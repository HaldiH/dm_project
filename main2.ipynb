# %%
import pandas as pd
import numpy as np
from rdkit.Chem import Descriptors, Descriptors3D, MolFromSmiles, Draw, Conformer

# %%
df = pd.read_csv('dataset/data.csv')

# %%
df
# Out:
#                      Chiral_Molecular_SMILES  Energy_(kcal/mol)  \
# 0                     Fc1ccc(cc1)c1cn[nH]c1N       -51177.14356
# 1                     Fc1ccc(cc1)c1cn[nH]c1N       -51177.14356
# 2       O=C(c1ccccc1)O[C@H]1c2ccccc2C(=O)N1C       -73542.31526
# 3       O=C(c1ccccc1)O[C@H]1c2ccccc2C(=O)N1C       -73542.31444
# 4      O=C(c1ccccc1)O[C@@H]1c2ccccc2C(=O)N1C       -73542.31445
# ...                                      ...                ...
# 39921      O=C(C(C(F)(F)F)C(F)(F)F)Nc1ccccn1      -107501.66260
# 39922              NC1CCN(CC1)c1ccccc1C(=O)N       -58369.62214
# 39923              NC1CCN(CC1)c1ccccc1C(=O)N       -58370.13063
# 39924                           ON=Cc1ccccc1       -32775.84555
# 39925                           ON=Cc1ccccc1       -32770.77652
#
#        Zero_point_energy_(kcal/mol@0K)  Enthalpy_(kcal/mol@298K)  \
# 0                            93.711236                101.010221
# ...

# %%
df = df.dropna(axis='columns')

# %%
smiles = df['Chiral_Molecular_SMILES']
alpha = np.unique(list(''.join(smiles)))
